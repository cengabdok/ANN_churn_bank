# %% [markdown]
# ![churn.JPG](attachment:churn.JPG)

# %% [markdown]
# **Background and Context**
#
# Businesses, including banks, face the challenge of customer churn, which refers to customers leaving one service provider and joining another. To address this issue, it is important for businesses to understand the factors that influence a customer's decision to leave. By identifying these factors, management can focus on improving the service in the areas that matter most to customers.
#
# **Objective**
#
# Create a neural network-based classifier that can accurately predict whether a bank customer will churn (leave) or not. This classifier will enable the bank to proactively identify customers who may be at risk of churning and take appropriate measures to retain them, ultimately helping the bank to retain customers and mitigate customer churn.

# %% [markdown]
# **About Dataset**
#
# **RowNumber:** Corresponds to the record (row) number and has no effect on the output.
#
# **CustomerId:** Contains random values and has no effect on customer leaving the bank.
#
# **Surname:** The surname of a customer has no impact on their decision to leave the bank.
#
# **CreditScore:** Can have an effect on customer churn, since a customer with a higher credit score is less likely to leave the bank.
#
# **Geography:** A customer’s location can affect their decision to leave the bank.
#
# **Gender:** It’s interesting to explore whether gender plays a role in a customer leaving the bank.
#
# **Age:** This is certainly relevant, since older customers are less likely to leave their bank than younger ones.
#
# **Tenure:** Refers to the number of years that the customer has been a client of the bank. Normally, older clients are more loyal and less likely to leave a bank.
#
# **Balance:** Also a very good indicator of customer churn, as people with a higher balance in their accounts are less likely to leave the bank compared to those with lower balances.
#
# **NumOfProducts:** Refers to the number of products that a customer has purchased through the bank.
#
# **HasCrCard:** Denotes whether or not a customer has a credit card. This column is also relevant, since people with a credit card are less likely to leave the bank.
#
# **IsActiveMember:** Active customers are less likely to leave the bank.
#
# **EstimatedSalary:** As with balance, people with lower salaries are more likely to leave the bank compared to those with higher salaries.
#
# **Exited:** Whether or not the customer left the bank.

# %% [markdown]
# # Keras Classification

# %% [markdown]
# ## Import  libraries & data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (5,3.5)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('churn.csv')

# %%
data = df.copy()

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age
# 0          1    15634602  Hargrave          619    France  Female   42  \
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember
# 0       2      0.000              1          1               1  \
# 1       1  83807.860              1          0               1
# 2       8 159660.800              3          1               0
# 3       1      0.000              2          0               0
# 4       2 125510.820              1          1               1
#
#    EstimatedSalary  Exited
# 0       101348.880       1
# 1       112542.580       0
# 2       113931.570       1
# 3        93826.630       0
# 4        79084.100       0

# %%
df.describe().T
# Out:
#                     count         mean       std          min          25%
# RowNumber       10000.000     5000.500  2886.896        1.000     2500.750  \
# CustomerId      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# CreditScore     10000.000      650.529    96.653      350.000      584.000
# Age             10000.000       38.922    10.488       18.000       32.000
# Tenure          10000.000        5.013     2.892        0.000        3.000
# Balance         10000.000    76485.889 62397.405        0.000        0.000
# NumOfProducts   10000.000        1.530     0.582        1.000        1.000
# HasCrCard       10000.000        0.706     0.456        0.000        0.000
# IsActiveMember  10000.000        0.515     0.500        0.000        0.000
# EstimatedSalary 10000.000   100090.240 57510.493       11.580    51002.110
# Exited          10000.000        0.204     0.403        0.000        0.000
#
#                          50%          75%          max
# RowNumber           5000.500     7500.250    10000.000
# CustomerId      15690738.000 15753233.750 15815690.000
# CreditScore          652.000      718.000      850.000
# Age                   37.000       44.000       92.000
# Tenure                 5.000        7.000       10.000
# Balance            97198.540   127644.240   250898.090
# NumOfProducts          1.000        2.000        4.000
# HasCrCard              1.000        1.000        1.000
# IsActiveMember         1.000        1.000        1.000
# EstimatedSalary   100193.915   149388.247   199992.480
# Exited                 0.000        0.000        1.000

# %%
for i in df.columns:
    df.rename(columns={i : i.lower()} ,inplace=True)

# %%
df.columns
# Out:
# Index(['rownumber', 'customerid', 'surname', 'creditscore', 'geography',
#        'gender', 'age', 'tenure', 'balance', 'numofproducts', 'hascrcard',
#        'isactivemember', 'estimatedsalary', 'exited'],
#       dtype='object')

# %%
df.exited.value_counts()
# Out:
# exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df.groupby('exited').isactivemember.value_counts(sorted)
# Out:
# exited  isactivemember
# 0       1                0.555
#         0                0.445
# 1       0                0.639
#         1                0.361
# Name: proportion, dtype: float64

# %%
sns.countplot(x= df.isactivemember,hue = df.exited,)
# Out:
# <Axes: xlabel='isactivemember', ylabel='count'>

# %%
df.groupby('exited').hascrcard.value_counts()
# Out:
# exited  hascrcard
# 0       1            5631
#         0            2332
# 1       1            1424
#         0             613
# Name: count, dtype: int64

# %%
sns.countplot(x= df.hascrcard,hue = df.exited,)
# Out:
# <Axes: xlabel='hascrcard', ylabel='count'>

# %%
sns.kdeplot(x = df.balance,hue=df.exited,fill= True);

# %%
sns.histplot(x =df.age,hue=df.exited,fill=True,bins=20);

# %%
sns.kdeplot(x = df.creditscore,hue=df.exited,fill= True);

# %%
df.columns
# Out:
# Index(['rownumber', 'customerid', 'surname', 'creditscore', 'geography',
#        'gender', 'age', 'tenure', 'balance', 'numofproducts', 'hascrcard',
#        'isactivemember', 'estimatedsalary', 'exited'],
#       dtype='object')

# %%
sns.countplot(x= df.geography,hue = df.exited);

# %%
sns.countplot(x= df.gender,hue = df.exited);

# %%
df_numeric = df.select_dtypes(exclude='object')
df_numeric
# Out:
#       rownumber  customerid  creditscore  age  tenure    balance
# 0             1    15634602          619   42       2      0.000  \
# 1             2    15647311          608   41       1  83807.860
# 2             3    15619304          502   42       8 159660.800
# 3             4    15701354          699   39       1      0.000
# 4             5    15737888          850   43       2 125510.820
# ...         ...         ...          ...  ...     ...        ...
# 9995       9996    15606229          771   39       5      0.000
# 9996       9997    15569892          516   35      10  57369.610
# 9997       9998    15584532          709   36       7      0.000
# 9998       9999    15682355          772   42       3  75075.310
# 9999      10000    15628319          792   28       4 130142.790
#
#       numofproducts  hascrcard  isactivemember  estimatedsalary  exited
# 0                 1          1               1       101348.880       1
# 1                 1          0               1       112542.580       0
# 2                 3          1               0       113931.570       1
# 3                 2          0               0        93826.630       0
# 4                 1          1               1        79084.100       0
# ...             ...        ...             ...              ...     ...
# 9995              2          1               0        96270.640       0
# 9996              1          1               1       101699.770       0
# 9997              1          0               1        42085.580       1
# 9998              2          1               0        92888.520       1
# 9999              1          1               0        38190.780       0
#
# [10000 rows x 11 columns]

# %%
df_numeric.drop(columns=['rownumber','customerid'],inplace=True)

# %%
df_numeric.corr()
# Out:
#                  creditscore    age  tenure  balance  numofproducts
# creditscore            1.000 -0.004   0.001    0.006          0.012  \
# age                   -0.004  1.000  -0.010    0.028         -0.031
# tenure                 0.001 -0.010   1.000   -0.012          0.013
# balance                0.006  0.028  -0.012    1.000         -0.304
# numofproducts          0.012 -0.031   0.013   -0.304          1.000
# hascrcard             -0.005 -0.012   0.023   -0.015          0.003
# isactivemember         0.026  0.085  -0.028   -0.010          0.010
# estimatedsalary       -0.001 -0.007   0.008    0.013          0.014
# exited                -0.027  0.285  -0.014    0.119         -0.048
#
#                  hascrcard  isactivemember  estimatedsalary  exited
# creditscore         -0.005           0.026           -0.001  -0.027
# age                 -0.012           0.085           -0.007   0.285
# tenure               0.023          -0.028            0.008  -0.014
# balance             -0.015          -0.010            0.013   0.119
# numofproducts        0.003           0.010            0.014  -0.048
# hascrcard            1.000          -0.012           -0.010  -0.007
# isactivemember      -0.012           1.000           -0.011  -0.156
# estimatedsalary     -0.010          -0.011            1.000   0.012
# exited              -0.007          -0.156            0.012   1.000

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(df_numeric.corr(), annot=True, cmap='rocket')
# Out:
# <Axes: >

# %%
df.drop(columns=['rownumber','customerid','surname'],inplace=True)

# %%
df = pd.get_dummies(df, drop_first=True).astype(int)
df.head()
# Out:
#    creditscore  age  tenure  balance  numofproducts  hascrcard
# 0          619   42       2        0              1          1  \
# 1          608   41       1    83807              1          0
# 2          502   42       8   159660              3          1
# 3          699   39       1        0              2          0
# 4          850   43       2   125510              1          1
#
#    isactivemember  estimatedsalary  exited  geography_Germany
# 0               1           101348       1                  0  \
# 1               1           112542       0                  0
# 2               0           113931       1                  0
# 3               0            93826       0                  0
# 4               1            79084       0                  0
#
#    geography_Spain  gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %% [markdown]
# ## Preprocessing of Data

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,OrdinalEncoder,MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix,precision_recall_curve,average_precision_score
from keras import models
from tensorflow.keras.layers import Dense, Activation 
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
X = df.drop(columns=['exited'],axis=1)  # burada da bazen values alinabilir
y = df.exited.values             # values alinacak

# %%
seed= 42
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    test_size=0.1,
                                                    random_state=seed)

# %%
scaler = MinMaxScaler()

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y, random_state=0)

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Modelling & Model Performance

# %% [markdown]
# ### without class_weigth

# %%
tf.random.set_seed(seed)

# %%
model = Sequential()

model.add(Dense(units=32,activation='relu'))
model.add(Dense(units=32,activation='tanh'))
model.add(Dense(units=16,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))

# %%
opt = Adam(lr = 0.001)

model.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['Recall'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=25)

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=128,
          epochs=200,
          verbose=1,
          callbacks=[early_stop])
# Out:
# Epoch 1/200
# 57/57 [==============================] - 2s 9ms/step - loss: 0.5090 - recall: 0.0000e+00 - val_loss: 0.4639 - val_recall: 0.0000e+00
# Epoch 2/200
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4706 - recall: 0.0000e+00 - val_loss: 0.4529 - val_recall: 0.0000e+00
# Epoch 3/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4592 - recall: 0.0014 - val_loss: 0.4423 - val_recall: 0.0000e+00
# Epoch 4/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4485 - recall: 0.0353 - val_loss: 0.4319 - val_recall: 0.0382
# Epoch 5/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4397 - recall: 0.0788 - val_loss: 0.4260 - val_recall: 0.0510
# Epoch 6/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4314 - recall: 0.1249 - val_loss: 0.4166 - val_recall: 0.1401
# Epoch 7/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4239 - recall: 0.1847 - val_loss: 0.4134 - val_recall: 0.1019
# Epoch 8/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4188 - recall: 0.2064 - val_loss: 0.4078 - val_recall: 0.1592
# Epoch 9/200
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4142 - recall: 0.2688 - val_loss: 0.4006 - val_recall: 0.1911
# Epoch 10/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4086 - recall: 0.2817 - val_loss: 0.3954 - val_recall: 0.2229
# Epoch 11/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4039 - recall: 0.3096 - val_loss: 0.3911 - val_recall: 0.3057
# Epoch 12/200
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4012 - recall: 0.3293 - val_loss: 0.3901 - val_recall: 0.2293
# Epoch 13/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3953 - recall: 0.3170 - val_loss: 0.3834 - val_recall: 0.2611
# Epoch 14/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3928 - recall: 0.3496 - val_loss: 0.3855 - val_recall: 0.2102
# Epoch 15/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3868 - recall: 0.3564 - val_loss: 0.3754 - val_recall: 0.3694
# Epoch 16/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3814 - recall: 0.3646 - val_loss: 0.3699 - val_recall: 0.3312
# Epoch 17/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3748 - recall: 0.3829 - val_loss: 0.3707 - val_recall: 0.4140
# Epoch 18/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3694 - recall: 0.3965 - val_loss: 0.3659 - val_recall: 0.4268
# Epoch 19/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.
200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3252 - recall: 0.4983 - val_loss: 0.3400 - val_recall: 0.5223
# Epoch 53/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3263 - recall: 0.5098 - val_loss: 0.3350 - val_recall: 0.4968
# Epoch 54/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3253 - recall: 0.5010 - val_loss: 0.3385 - val_recall: 0.4904
# Epoch 55/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3231 - recall: 0.5207 - val_loss: 0.3352 - val_recall: 0.4395
# Epoch 56/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3239 - recall: 0.5071 - val_loss: 0.3381 - val_recall: 0.4459
# Epoch 57/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3248 - recall: 0.4997 - val_loss: 0.3372 - val_recall: 0.4777
# Epoch 58/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3240 - recall: 0.5085 - val_loss: 0.3347 - val_recall: 0.4522
# Epoch 59/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3235 - recall: 0.5051 - val_loss: 0.3387 - val_recall: 0.4395
# Epoch 60/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3231 - recall: 0.5119 - val_loss: 0.3371 - val_recall: 0.4395
# Epoch 61/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3228 - recall: 0.5064 - val_loss: 0.3381 - val_recall: 0.4713
# Epoch 62/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3226 - recall: 0.5098 - val_loss: 0.3396 - val_recall: 0.5223
# Epoch 63/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3224 - recall: 0.5098 - val_loss: 0.3368 - val_recall: 0.5223
# Epoch 64/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3247 - recall: 0.5085 - val_loss: 0.3401 - val_recall: 0.5159
# Epoch 65/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3211 - recall: 0.5146 - val_loss: 0.3398 - val_recall: 0.5032
# Epoch 66/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3225 - recall: 0.5112 - val_loss: 0.3425 - val_recall: 0.5096
# Epoch 67/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3228 - recall: 0.5126 - val_loss: 0.3340 - val_recall: 0.4459
# Epoch 68/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3220 - recall: 0.5071 - val_loss: 0.3391 - val_recall: 0.4968
# Epoch 69/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3225 - recall: 0.5098 - val_loss: 0.3362 - val_recall: 0.4841
# Epoch 70/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3223 - recall: 0.5112 - val_loss: 0.3430 - val_recall: 0.4140
# Epoch 71/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3215 - recall: 0.5085 - val_loss: 0.3393 - val_recall: 0.5159
# Epoch 72/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3222 - recall: 0.5166 - val_loss: 0.3399 - val_recall: 0.5478
# Epoch 73/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3204 - recall: 0.5146 - val_loss: 0.3492 - val_recall: 0.5732
# Epoch 74/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3236 - recall: 0.5187 - val_loss: 0.3383 - val_recall: 0.4395
# Epoch 75/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3204 - recall: 0.5126 - val_loss: 0.3383 - val_recall: 0.4522
# Epoch 75: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                192
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 337
# Trainable params: 337
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#    loss  recall  val_loss  val_recall
# 0 0.509   0.000     0.464       0.000
# 1 0.471   0.000     0.453       0.000
# 2 0.459   0.001     0.442       0.000
# 3 0.448   0.035     0.432       0.038
# 4 0.440   0.079     0.426       0.051

# %%
loss_df.plot()
# Out:
# <Axes: >

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")  # to convert the probabilities into binary values
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 2ms/step
# [[1528   65]
#  [ 226  181]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      1593
#            1       0.74      0.44      0.55       407
#
#     accuracy                           0.85      2000
#    macro avg       0.80      0.70      0.73      2000
# weighted avg       0.84      0.85      0.84      2000

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6772946747550742

# %% [markdown]
# ### with class_weigth

# %%
model = Sequential()

tf.random.set_seed(seed)

model.add(Dense(units=32,activation='relu'))
model.add(Dense(units=32,activation='tanh'))
model.add(Dense(units=16,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))

opt = Adam(lr=0.001)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                  classes=np.unique(y_train),
                                                  y=y_train)

class_weights = {0: class_weights[0], 1: class_weights[1]}
class_weights
# Out:
# {0: 0.6279434850863422, 1: 2.4539877300613497}

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=128,
          epochs=200,
          verbose=1,
          callbacks=[early_stop],
          class_weight=class_weights)
# Out:
# Epoch 1/200
# 57/57 [==============================] - 3s 14ms/step - loss: 0.6582 - recall: 0.5961 - val_loss: 0.6695 - val_recall: 0.7261
# Epoch 2/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6200 - recall: 0.6802 - val_loss: 0.5569 - val_recall: 0.5860
# Epoch 3/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6000 - recall: 0.6782 - val_loss: 0.5591 - val_recall: 0.6879
# Epoch 4/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5829 - recall: 0.7020 - val_loss: 0.5589 - val_recall: 0.7197
# Epoch 5/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5707 - recall: 0.7013 - val_loss: 0.5404 - val_recall: 0.6879
# Epoch 6/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5546 - recall: 0.7244 - val_loss: 0.5202 - val_recall: 0.7070
# Epoch 7/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5376 - recall: 0.7284 - val_loss: 0.4995 - val_recall: 0.7134
# Epoch 8/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5175 - recall: 0.7373 - val_loss: 0.4966 - val_recall: 0.7516
# Epoch 9/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5002 - recall: 0.7671 - val_loss: 0.5027 - val_recall: 0.7643
# Epoch 10/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4912 - recall: 0.7637 - val_loss: 0.4881 - val_recall: 0.7643
# Epoch 11/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4832 - recall: 0.7563 - val_loss: 0.5252 - val_recall: 0.8089
# Epoch 12/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4791 - recall: 0.7685 - val_loss: 0.4766 - val_recall: 0.7643
# Epoch 13/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4728 - recall: 0.7563 - val_loss: 0.4649 - val_recall: 0.7643
# Epoch 14/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4685 - recall: 0.7726 - val_loss: 0.4655 - val_recall: 0.7580
# Epoch 15/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4667 - recall: 0.7794 - val_loss: 0.4708 - val_recall: 0.7580
# Epoch 16/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4621 - recall: 0.7699 - val_loss: 0.4720 - val_recall: 0.7643
# Epoch 17/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4596 - recall: 0.7739 - val_loss: 0.5106 - val_recall: 0.7771
# Epoch 18/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4578 - recall: 0.7685 - val_loss: 0.5122 - val_recall: 0.8089
# Epoch 19/200
# 57/57 [==============================] - 0s 8ms/step - loss: 0.4559 - recall: 0.7665 - val_loss: 0.4695 - val_recall: 0.7771
# Epoch 20/200
# 57/57 [==============================] - 0s 7ms/step - loss: 0.4549 - recall: 0.7766 - val_loss: 0.4543 - val_recall: 0.7707
# Epoch 21/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4546 - recall: 0.7780 - val_loss: 0.4614 - val_recall: 0.7389
# Epoch 22/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4529 - recall: 0.7760 - val_loss: 0.4793 - val_recall: 0.7580
# Epoch 23/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4493 - recall: 0.7821 - val_loss: 0.4607 - val_recall: 0.7452
# Epoch 24/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4497 - recall: 0.7794 - val_loss: 0.4501 - val_recall: 0.7325
# Epoch 25/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4492 - recall: 0.7726 - val_loss: 0.4543 - val_recall: 0.7580
# Epoch 26/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4468 - recall: 0.7814 - val_loss: 0.4891 - val_recall: 0.7516
# Epoch 27/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4469 - recall: 0.7882 - val_loss: 0.4791 - val_recall: 0.7516
# Epoch 28/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4462 - recall: 0.7834 - val_loss: 0.4350 - val_recall: 0.7325
# Epoch 29/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4465 - recall: 0.7753 - val_loss: 0.4919 - val_recall: 0.7580
# Epoch 30/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4452 - recall: 0.7848 - val_loss: 0.4565 - val_recall: 0.7707
# Epoch 31/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4435 - recall: 0.7787 - val_loss: 0.4680 - val_recall: 0.7643
# Epoch 32/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.
]
#               precision    recall  f1-score   support
#
#            0       0.93      0.77      0.85      1593
#            1       0.47      0.77      0.58       407
#
#     accuracy                           0.77      2000
#    macro avg       0.70      0.77      0.71      2000
# weighted avg       0.84      0.77      0.79      2000

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
ey_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Prcision-Recall curve')
plt.show()
# Out:
# 63/63 [==============================] - 0s 5ms/step

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6772946747550742

# %% [markdown]
# ## Final Model and Model Deployment

# %%
import pickle 

pickle.dump(scaler,open('scaler_churn','wb'))

# %%
model = Sequential()

tf.random.set_seed(seed)

model.add(Dense(units=32,activation='relu'))
model.add(Dense(units=32,activation='tanh'))
model.add(Dense(units=16,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))

opt = Adam(lr=0.001)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=128,
          epochs=200,
          verbose=1,
          callbacks=[early_stop],
          class_weight=class_weights)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/200
# 57/57 [==============================] - 2s 12ms/step - loss: 0.6668 - recall: 0.6395 - val_loss: 0.6619 - val_recall: 0.6688
# Epoch 2/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6243 - recall: 0.6660 - val_loss: 0.5591 - val_recall: 0.5669
# Epoch 3/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6040 - recall: 0.6762 - val_loss: 0.5712 - val_recall: 0.6624
# Epoch 4/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5884 - recall: 0.7013 - val_loss: 0.5634 - val_recall: 0.6879
# Epoch 5/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5789 - recall: 0.6938 - val_loss: 0.5413 - val_recall: 0.6624
# Epoch 6/200
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5679 - recall: 0.7047 - val_loss: 0.5292 - val_recall: 0.6561
# Epoch 7/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5589 - recall: 0.7128 - val_loss: 0.5167 - val_recall: 0.6815
# Epoch 8/200
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5480 - recall: 0.7074 - val_loss: 0.4966 - val_recall: 0.6879
# Epoch 9/200
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5360 - recall: 0.7298 - val_loss: 0.5135 - val_recall: 0.7516
# Epoch 10/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5190 - recall: 0.7379 - val_loss: 0.4919 - val_recall: 0.7325
# Epoch 11/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5059 - recall: 0.7427 - val_loss: 0.5464 - val_recall: 0.8217
# Epoch 12/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4960 - recall: 0.7570 - val_loss: 0.4742 - val_recall: 0.7580
# Epoch 13/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4863 - recall: 0.7529 - val_loss: 0.4927 - val_recall: 0.7834
# Epoch 14/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4816 - recall: 0.7604 - val_loss: 0.4484 - val_recall: 0.7197
# Epoch 15/200
# 57/57 [==============================] - 1s 9ms/step - loss: 0.4788 - recall: 0.7692 - val_loss: 0.4585 - val_recall: 0.7516
# Epoch 16/200
# 57/57 [==============================] - 0s 7ms/step - loss: 0.4756 - recall: 0.7651 - val_loss: 0.4989 - val_recall: 0.7962
# Epoch 17/200
# 57/57 [==============================] - 0s 8ms/step - loss: 0.4754 - recall: 0.7685 - val_loss: 0.5341 - val_recall: 0.7962
# Epoch 18/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.4724 - recall: 0.7678 - val_loss: 0.5317 - val_recall: 0.8153
# Epoch 19/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.4716 - recall: 0.7658 - val_loss: 0.4890 - val_recall: 0.7898
# Epoch 20/200
# 57/57 [==============================] - 0s 7ms/step - loss: 0.4689 - recall: 0.7699 - val_loss: 0.4814 - val_recall: 0.7771
# Epoch 21/200
# 57/57 [==============================] - 0s 7ms/step - loss: 0.4691 - recall: 0.7719 - val_loss: 0.4743 - val_recall: 0.7643
# Epoch 22/200
# 57/57 [==============================] - 0s 7ms/step - loss: 0.4665 - recall: 0.7699 - val_loss: 0.4772 - val_recall: 0.7707
# Epoch 23/200
# 57/57 [==============================] - 0s 7ms/step - loss: 0.4651 - recall: 0.7685 - val_loss: 0.4833 - val_recall: 0.7771
# Epoch 24/200
# 57/57 [==============================] - 1s 9ms/step - loss: 0.4658 - recall: 0.7753 - val_loss: 0.4727 - val_recall: 0.7707
# Epoch 25/200
# 57/57 [==============================] - 0s 8ms/step - loss: 0.
200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4413 - recall: 0.7834 - val_loss: 0.4469 - val_recall: 0.7452
# Epoch 57/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4418 - recall: 0.7834 - val_loss: 0.4952 - val_recall: 0.7707
# Epoch 58/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4423 - recall: 0.7794 - val_loss: 0.4561 - val_recall: 0.7516
# Epoch 59/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4404 - recall: 0.7787 - val_loss: 0.4287 - val_recall: 0.7070
# Epoch 60/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4408 - recall: 0.7862 - val_loss: 0.4458 - val_recall: 0.7389
# Epoch 61/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4406 - recall: 0.7800 - val_loss: 0.4546 - val_recall: 0.7580
# Epoch 62/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4393 - recall: 0.7678 - val_loss: 0.4895 - val_recall: 0.7707
# Epoch 63/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4395 - recall: 0.7848 - val_loss: 0.4775 - val_recall: 0.7771
# Epoch 64/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4428 - recall: 0.7787 - val_loss: 0.5257 - val_recall: 0.8153
# Epoch 65/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4366 - recall: 0.7787 - val_loss: 0.4755 - val_recall: 0.7707
# Epoch 66/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4357 - recall: 0.7800 - val_loss: 0.4692 - val_recall: 0.7707
# Epoch 67/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4366 - recall: 0.7800 - val_loss: 0.4502 - val_recall: 0.7516
# Epoch 68/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4352 - recall: 0.7733 - val_loss: 0.4983 - val_recall: 0.7834
# Epoch 69/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4354 - recall: 0.7834 - val_loss: 0.4965 - val_recall: 0.7898
# Epoch 70/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4337 - recall: 0.7882 - val_loss: 0.4444 - val_recall: 0.7452
# Epoch 71/200
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4337 - recall: 0.7787 - val_loss: 0.5008 - val_recall: 0.7898
# Epoch 72/200
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4365 - recall: 0.7875 - val_loss: 0.5003 - val_recall: 0.7771
# Epoch 72: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <Axes: >

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("recall : ", recall)
# Out:
# loss :  0.4975948631763458
# recall :  0.773955762386322

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 2ms/step
# [[1186  407]
#  [  92  315]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.83      1593
#            1       0.44      0.77      0.56       407
#
#     accuracy                           0.75      2000
#    macro avg       0.68      0.76      0.69      2000
# weighted avg       0.83      0.75      0.77      2000

# %%
model.save('model_churn.h5')

# %% [markdown]
# ### Prediction

# %%
single_customer = df.drop('exited', axis=1).iloc[0]
single_customer
# Out:
# creditscore             619
# age                      42
# tenure                    2
# balance                   0
# numofproducts             1
# hascrcard                 1
# isactivemember            1
# estimatedsalary      101348
# geography_Germany         0
# geography_Spain           0
# gender_Male               0
# Name: 0, dtype: int32

# %%
single_customer = scaler.transform(single_customer.values.reshape(-1, 11))
single_customer
# Out:
# array([[0.538     , 0.32432432, 0.2       , 0.        , 0.        ,
#         1.        , 1.        , 0.50673314, 0.        , 0.        ,
#         0.        ]])

# %%
y_pred =(model.predict(single_customer) > 0.5).astype("int32")
y_pred
# Out:
# 1/1 [==============================] - 0s 57ms/step
# array([[1]])

# %%
df["exited"].iloc[0]
# Out:
# 1

# %% [markdown]
# ## Comparison with ML

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression(class_weight='balanced')
log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1119  474]
#  [ 119  288]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.79      1593
#            1       0.38      0.71      0.49       407
#
#     accuracy                           0.70      2000
#    macro avg       0.64      0.71      0.64      2000
# weighted avg       0.80      0.70      0.73      2000

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(class_weight='balanced')
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1548   45]
#  [ 226  181]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1593
#            1       0.80      0.44      0.57       407
#
#     accuracy                           0.86      2000
#    macro avg       0.84      0.71      0.75      2000
# weighted avg       0.86      0.86      0.85      2000

# %% [markdown]
# ![image.png](attachment:image.png)
